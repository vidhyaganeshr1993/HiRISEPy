# %%
import sys
import os

sys.path.insert(
    0,
    "/Users/yourname/HiRISE_Python"
)

from hirisepy.batch import process_hirise_folder

print("HiRISE pipeline ready")

# %%
input_folder = "/Volumes/MyExternalDrive/HiRISE_Data/input"

qc_folder = "/Volumes/MyExternalDrive/HiRISE_Data/qc"

corrected_folder = "/Volumes/MyExternalDrive/HiRISE_Data/corrected"

summary_csv = "/Volumes/MyExternalDrive/HiRISE_Data/batch_summary.csv"

# %%
results = process_hirise_folder(
    input_folder,
    qc_folder,
    corrected_folder,
    summary_csv
)
